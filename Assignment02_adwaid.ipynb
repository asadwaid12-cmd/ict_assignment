# %% [markdown]
# <a href="https://colab.research.google.com/github/asadwaid12-cmd/ict_assignment/blob/main/Assignment02_adwaid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Qustion 1

# %%
n=int(input("enter the number"))
if n%3==0 and n%5==0:
    print("Fizzbuzz")
elif n%3==0:
    print("Fizz")
elif n%5==0:
    print("buzz")
else:
    print(n)
# Out:
# enter the number15
# Fizzbuzz

# %% [markdown]
# Question 2

# %%
n=int(input("enter the number of unit consumed : "))
totalamount = 0

if n<=100:
   totalamount = n*5
elif n <= 200:
   totalamount = (100*5) + (n-100) * 7
else:
   totalamount = (100*5) + (100*7)+((n-200)*10)
print(f"Total Bill amount :{totalamount}")
# Out:
# enter the number of unit consumed : 245
# Total Bill amount :1650

# %% [markdown]
# Question 3

# %%
for i in range(1, 6):
  print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# Question 4

# %%
pal = str(input("Enter a number or string:"))
rev_pal = pal[::-1]
if rev_pal == pal:
  print(pal,"is a palindrome")
else:
  print(pal,"is not a palindrome")
# Out:
# Enter a number or string:121
# 121 is a palindrome
