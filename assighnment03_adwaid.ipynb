# %% [markdown]
# <a href="https://colab.research.google.com/github/asadwaid12-cmd/ict_assignment/blob/main/assighnment03_adwaid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***ASSIGHNMENT 3***

# %% [markdown]
# **QUESTION 1**

# %%
# Write a Python function to find the Max of three numbers

# %%
max(12,33,45)
# Out:
# 45

# %% [markdown]
# **QUESTION 2**

# %%
#Write a Python function to sum all the numbers in a list.

# %%
list1 = [18,12,30,10,7]
sum=0
for i in list1:
  sum=sum+i
print(sum)
# Out:
# 77

# %% [markdown]
# **QUESTION 3**

# %%
 #Python program to insert a number to any position in a list (Get the number
#to be inserted and position from the user)

# %%
number = [23,44,55,77,99]

# %%
number.insert(2,88)

# %%
number
# Out:
# [23, 44, 88, 55, 77, 99]

# %% [markdown]
# **QUETION 4**

# %%
dict1 = { "name": "Kelly", "age":25, "salary": 8000, "city": "New york"}
dict1['location'] = dict1.pop('city')
print(dict1)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %% [markdown]
# **QUESTION 5**

# %%
#Write a Python program to change Brad’s salary to 8500 in the following
#dictionary.
#sample_dict = {
 #'emp1': {'name': 'Jhon', 'salary': 7500},
 #'emp2': {'name': 'Emma', 'salary': 8000},
 #'emp3': {'name': 'Brad', 'salary': 5

# %%
dict1 = {
    'list1': {'name': 'Jhon', 'salary': 7500},
    'list2': {'name': 'Emma', 'salary': 8000},
    'list3': {'name': 'Brad', 'salary': 5}
}

dict1['list3']['salary'] = 8500
print(dict1)
# Out:
# {'list1': {'name': 'Jhon', 'salary': 7500}, 'list2': {'name': 'Emma', 'salary': 8000}, 'list3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# **QUESTION 6**

# %%
 #Write a program to copy elements 44 and 55 from the following tuple into a
#new tuple. Given: tuple1 = (11, 22, 33, 44, 55, 66)

# %%
t1 = (11, 22, 33, 44, 55, 66)
t2 = t1[3:-1]
print(t2)
# Out:
# (44, 55)

# %% [markdown]
# **QUESTION 7**

# %%
#Counts the number of occurrences of item 50 from a tuple tuple1 = (50, 10,
#60, 70, 50,83,567,50,81

# %%
t1 = (50, 10, 60, 70, 50, 83, 567, 50, 81)
count_50 = t1.count(50)
print(f"The number of occurrences of 50 is: {count_50}")
# Out:
# The number of occurrences of 50 is: 3
